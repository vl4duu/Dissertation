# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from scikit-learn import cross_validation as cv

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
